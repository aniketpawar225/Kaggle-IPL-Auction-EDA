# %% [markdown]
# <a href="https://www.kaggle.com/code/aniketpawar22/ipl-auction-eda?scriptVersionId=125028689" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # IPL 2023 Auction EDA

# %% [markdown]
# **As we know BCCI just now concluded the IPL 2023 auction and some of players got very high price so I will generate key insights from data using Pandas to clean data and then will use Matplotlib,Plotly for visualization****

# %% [markdown]
# # ****Importing required libraries****

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # **Import the required datasets**

# %%
df=pd.read_csv('/kaggle/input/ipl-auction-2022/2023 Auction/IPL_2023_Auction_Sold.csv')
df.head()
# Out:
#    Set No. 2023 Set First Name  Surname       Country Association         DOB  \
# 0        1      BA1     Mayank  Agarwal         India        KSCA  16/02/1991
# 1        1      BA1      Harry    Brook       England           F  22/02/1999
# 2        1      BA1    Ajinkya   Rahane         India         MCA  06/06/1988
# 3        1      BA1        Joe     Root       England           F  30/12/1990
# 4        1      BA1      Rilee  Rossouw  South Africa           F  09/10/1989
#
#    Age Specialism Batting_Style  ... ODI caps  T20 caps  IPL  \
# 0   32    BATSMAN           RHB  ...        5         0  113
# 1   24    BATSMAN           RHB  ...        0        20    0
# 2   34    BATSMAN           RHB  ...       90        20  158
# 3   32    BATSMAN           RHB  ...      158        32    0
# 4   33    BATSMAN           LHB  ...       36        26    5
#
#      Previous IPLTeam(s)   2022 Team 2022 IPL   C/U/A  Reserve_Price TEAM  \
# 0    RCB, DD, RPSG, PBKS        PBKS       13  Capped            100  SRH
# 1             Do No Play  Do No Play        0  Capped            150  SRH
# 2  MI, RPSG, RR, DC, KKR         KKR        7  Capped             50  CSK
# 3             Do No Play  Do No Play        0  Capped            100   RR
# 4                    RCB  Do No Play        0  Capped            200   DC
#
#    Auction_Price
# 0          825.0
# 1         1325.0
# 2           50.0
# 3          100.0
# 4          460.0
#
# [5 rows x 22 columns]

# %% [markdown]
# **From above dataset we will remove the unwanted columns whoch are not needed for our analysis**

# %%
df.drop(['Set No.','2023 Set','Association','DOB','Batting_Style','ODI caps','T20 caps','Previous IPLTeam(s)'],axis=1,inplace=True)

# %%
df.head()
# Out:
#   First Name  Surname       Country  Age Specialism       Bowling_Style  \
# 0     Mayank  Agarwal         India   32    BATSMAN  RIGHT ARM Off Spin
# 1      Harry    Brook       England   24    BATSMAN    RIGHT ARM Medium
# 2    Ajinkya   Rahane         India   34    BATSMAN                   -
# 3        Joe     Root       England   32    BATSMAN  RIGHT ARM Off Spin
# 4      Rilee  Rossouw  South Africa   33    BATSMAN                   -
#
#    Test caps  IPL   2022 Team  2022 IPL   C/U/A  Reserve_Price TEAM  \
# 0         21  113        PBKS        13  Capped            100  SRH
# 1          1    0  Do No Play         0  Capped            150  SRH
# 2         82  158         KKR         7  Capped             50  CSK
# 3        124    0  Do No Play         0  Capped            100   RR
# 4          0    5  Do No Play         0  Capped            200   DC
#
#    Auction_Price
# 0          825.0
# 1         1325.0
# 2           50.0
# 3          100.0
# 4          460.0

# %% [markdown]
# # Data Preparation & Cleaning

# %% [markdown]
# **I am combining the first name and surname columns into single player name columns which will be easy to read and also will save memory**

# %%
df['Player Name']=df[['First Name','Surname']].apply(lambda x:' '.join(x),axis=1)
df.drop(['First Name','Surname'],axis=1,inplace=True)

# %% [markdown]
# **Will look for unique values**

# %%
country=df['Country'].unique()
print("From following countries the players participated -",country)
# Out:
# From following countries the players participated - ['India' 'England' 'South Africa' 'New Zealand' 'Australia' 'Bangladesh'
#  'West Indies' 'Zimbabwe' 'Sri Lanka' 'Afghanistan' 'Ireland' 'Netherland'
#  'UAE' 'Namibia']

# %%
player_speciality=df['Specialism'].unique()
print("We have following specialisation from each player -",player_speciality)
# Out:
# We have following specialisation from each player - ['BATSMAN' 'ALL-ROUNDER' 'WICKETKEEPER' 'BOWLER']

# %%
bowling_style=df['Bowling_Style'].unique()
bowling_style
# Out:
# array(['RIGHT ARM Off Spin', 'RIGHT ARM Medium', '-',
#        'LEFT ARM Fast Medium', 'RIGHT ARM Fast', 'LEFT ARM Slow Orthodox',
#        'RIGHT ARM Fast Medium', 'LEFT ARM Fast', 'RIGHT ARM Leg Spin',
#        'LEFT ARM Slow Unorthodox', 'LEFT ARM Medium'], dtype=object)

# %% [markdown]
# **Teams participating in IPL Auction 2023**

# %%
df['TEAM'].unique()
# Out:
# array(['SRH', 'CSK', 'RR', 'DC', 'GT', 'PBKS', 'MI', 'KKR', 'UnSold',
#        'LSG', 'RCB'], dtype=object)

# %% [markdown]
# **Here UnSold is wrong value so we will drop that**

# %%
df.drop(df[df['TEAM']=='UnSold'].index,inplace=True)

# %%
t=df['TEAM'].unique()
print('Following teams were part of IPL Auction 2023 -',t)
# Out:
# Following teams were part of IPL Auction 2023 - ['SRH' 'CSK' 'RR' 'DC' 'GT' 'PBKS' 'MI' 'KKR' 'LSG' 'RCB']

# %% [markdown]
# # Data Visualization & Question Answering

# %% [markdown]
# **1. **From which country players earned more money****

# %%
money=df.groupby('Player Name')['Auction_Price'].mean()
top10_players=money.sort_values(ascending=False).head(10)
top10_players
# Out:
# Player Name
# Sam Curran          1850.0
# Cameron Green       1750.0
# Ben Stokes          1625.0
# Nicholas Pooran     1600.0
# Harry Brook         1325.0
# Mayank Agarwal       825.0
# Shivam Mavi          600.0
# Jason Holder         575.0
# Mukesh Kumar         550.0
# Heinrich Klaasen     525.0
# Name: Auction_Price, dtype: float64

# %%
fig=px.bar(x=top10_players.index,y=top10_players.values,color=top10_players.index,text=top10_players.values,title='Top10 Paid Players')
fig.update_layout(xaxis_title='Players',yaxis_title='Amount in Lakhs')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="345043c3-459a-4a7a-a74f-e70189ea2245" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("345043c3-459a-4a7a-a74f-e70189ea2245")) {                    Plotly.newPlot(                        "345043c3-459a-4a7a-a74f-e70189ea2245",                        [{"alignmentgroup":"True","hovertemplate":"color=Sam Curran<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"Sam Curran","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sam Curran","offsetgroup":"Sam Curran","orientation":"v","showlegend":true,"text":[1850.0],"textposition":"auto","x":["Sam Curran"],"xaxis":"x","y":[1850.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Cameron Green<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"Cameron Green","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Cameron Green","offsetgroup":"Cameron Green","orientation":"v","showlegend":true,"text":[1750.0],"textposition":"auto","x":["Cameron Green"],"xaxis":"x","y":[1750.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Ben Stokes<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"Ben Stokes","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Ben Stokes","offsetgroup":"Ben Stokes","orientation":"v","showlegend":true,"text":[1625.0],"textposition":"auto","x":["Ben Stokes"],"xaxis":"x","y":[1625.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Nicholas Pooran<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"Nicholas Pooran","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Nicholas Pooran","offsetgroup":"Nicholas Pooran","orientation":"v","showlegend":true,"text":[1600.0],"textposition":"auto","x":["Nicholas Pooran"],"xaxis":"x","y":[1600.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Harry Brook<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"Harry Brook","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Harry Brook","offsetgroup":"Harry Brook","orientation":"v","showlegend":true,"text":[1325.0],"textposition":"auto","x":["Harry Brook"],"xaxis":"x","y":[1325.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Mayank Agarwal<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"Mayank Agarwal","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Mayank Agarwal","offsetgroup":"Mayank Agarwal","orientation":"v","showlegend":true,"text":[825.0],"textposition":"auto","x":["Mayank Agarwal"],"xaxis":"x","y":[825.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Shivam Mavi<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"Shivam Mavi","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Shivam Mavi","offsetgroup":"Shivam Mavi","orientation":"v","showlegend":true,"text":[600.0],"textposition":"auto","x":["Shivam Mavi"],"xaxis":"x","y":[600.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Jason Holder<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"Jason Holder","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Jason Holder","offsetgroup":"Jason Holder","orientation":"v","showlegend":true,"text":[575.0],"textposition":"auto","x":["Jason Holder"],"xaxis":"x","y":[575.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"color=Mukesh Kumar<br>x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"Mukesh Kumar","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Mukesh Kumar","offsetgroup":"Mukesh Kumar","orientation":"v","showlegend":true,"text":[550.0],"textposition":"auto","x":["Mukesh Kumar"],"xaxis": ...

# %% [markdown]
# **Here we can see that top 3 paid players are Sam Curran,Cameron Green & Ben Stokes who all are foreign country players as well as All rounders so this years IPL auction was dominated by foreign players rather than Indian Player in terms of money and teams are ready to pay heavy amount if player is All rounder**

# %% [markdown]
# **2. **How many players are capped and Uncapped.Here Capped means played internation match and Uncapped means et to play internation match****

# %%
a=df['C/U/A'].value_counts()
fig1=px.pie(a,names=a.index,values=a.values,title='Capped/Uncapped Players')
fig1.update_traces(textposition='inside',textinfo='percent + label')
# Out:
# <div>                            <div id="ae1660b6-58e5-4e8b-bf37-6ce3f8ae8229" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae1660b6-58e5-4e8b-bf37-6ce3f8ae8229")) {                    Plotly.newPlot(                        "ae1660b6-58e5-4e8b-bf37-6ce3f8ae8229",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>value=%{value}<extra></extra>","labels":["Uncapped","Capped","Associate"],"legendgroup":"","name":"","showlegend":true,"values":[37,36,1],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"patt ...
#
# var gd = document.getElementById('ae1660b6-58e5-4e8b-bf37-6ce3f8a

# %% [markdown]
# **Nearly 70% players were uncapped means yet to make international apperance who were part of IPL Auction 2023**

# %% [markdown]
# **3. **What is percentage speciality of players****

# %%
b=df['Specialism'].value_counts()
fig2=px.pie(b,names=b.index,values=b.values,title='Speciality of Players')
fig2.update_traces(textposition='inside',textinfo='percent + label')
# Out:
# <div>                            <div id="a1fbbc77-c877-4507-a9cd-76dbb484e916" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1fbbc77-c877-4507-a9cd-76dbb484e916")) {                    Plotly.newPlot(                        "a1fbbc77-c877-4507-a9cd-76dbb484e916",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"index=%{label}<br>value=%{value}<extra></extra>","labels":["ALL-ROUNDER","BOWLER","BATSMAN","WICKETKEEPER"],"legendgroup":"","name":"","showlegend":true,"values":[27,26,12,9],"type":"pie","textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram ...
#
# var gd = document.getElementById('a1fbbc77-c877-

# %% [markdown]
# **Most of the players are either All rounders or Bowlers followed by Batsman & Wicketkeeper**

# %% [markdown]
# **4. Money paid according to player type**

# %%
c=df.groupby('Specialism')['Auction_Price'].mean()
fig3=px.bar(c,x=c.values,y=c.index,title='Average Money spent according to Player Type')
fig3.update_layout(xaxis_title='Avg. price in Lakhs')
# Out:
# <div>                            <div id="ca73b208-a53f-4350-bab7-94636c7ad222" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca73b208-a53f-4350-bab7-94636c7ad222")) {                    Plotly.newPlot(                        "ca73b208-a53f-4350-bab7-94636c7ad222",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>Specialism=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","x":[261.2962962962963,304.1666666666667,122.5,278.3333333333333],"xaxis":"x","y":["ALL-ROUNDER","BATSMAN","BOWLER","WICKETKEEPER"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"sc ...

# %% [markdown]
# **Batsmans got paid paid heavily followed by All rounders & WeeketKeepers**

# %% [markdown]
# **5. **How much money each team spent****

# %%
d=df.groupby('TEAM')['Auction_Price'].mean()
fig4=px.bar(d,x=d.index,y=d.values,color=d.values,text=d.index,title='Money spent by teams in Auction')
fig4.update_layout(xaxis_title='Teams',yaxis_title='Avg money in Lakhs')
# Out:
# <div>                            <div id="f9e7f372-9441-4ee2-ae5a-b1e72162e0c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f9e7f372-9441-4ee2-ae5a-b1e72162e0c3")) {                    Plotly.newPlot(                        "f9e7f372-9441-4ee2-ae5a-b1e72162e0c3",                        [{"alignmentgroup":"True","hovertemplate":"TEAM=%{text}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[270.7142857142857,300.0,226.66666666666666,64.28571428571429,198.0,256.25,396.0,100.0,133.57142857142858,295.4166666666667],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":["CSK","DC","GT","KKR","LSG","MI","PBKS","RCB","RR","SRH"],"textposition":"auto","x":["CSK","DC","GT","KKR","LSG","MI","PBKS","RCB","RR","SRH"],"xaxis":"x","y":[270.7142857142857,300.0,226.66666666666666,64.28571428571429,198.0,256.25,396.0,100.0,133.57142857142858,295.4166666666667],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0 ...

# %% [markdown]
# **PBKS(Punjab)spent the most money in this years IPL auction**

# %% [markdown]
# **Country wise paid players**

# %%
df.drop(df[df['Auction_Price']< 0.0].index,inplace=True)

# %%
country=df.groupby('Country')['Auction_Price'].mean()
z=country.head()
fig5=px.bar(x=z.index,y=z.values,title='Countries with top5 paid players',text=z.index)
fig5.update_layout(xaxis_title='Country',yaxis_title='Price in Lakhs')
# Out:
# <div>                            <div id="22968dc4-1f22-458d-9706-65779c014f56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("22968dc4-1f22-458d-9706-65779c014f56")) {                    Plotly.newPlot(                        "22968dc4-1f22-458d-9706-65779c014f56",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":["Afghanistan","Australia","Bangladesh","England","India"],"textposition":"auto","x":["Afghanistan","Australia","Bangladesh","England","India"],"xaxis":"x","y":[50.0,531.25,100.0,726.25,86.44444444444444],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scat ...

# %% [markdown]
# **England players got high biddings followed by Australia**
